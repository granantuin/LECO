# %%
# !pip install -r "/content/drive/MyDrive/Colab Notebooks/LEVX_1km/requirements.txt"

# %%
# !pip install lazypredict

# %%
import plotly.express as px
import pandas as pd
import numpy as np
coor=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LECO/input_files/distan_lat43.302lon-8.377p4R4Km.csv")
px.set_mapbox_access_token("pk.eyJ1IjoiZ3JhbmFudHVpbiIsImEiOiJja3B4dGU4OTkwMTFmMm9ycnNhMjJvaGJqIn0.VWzx_PkD9A5cSUVsn_ijCA")
px.scatter_mapbox(coor, hover_data=['distance'],lat='lat', lon='lon',color='distance', title="Nearest points",
                           color_continuous_scale=px.colors.cyclical.IceFire,)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5e357856-224a-42e6-8737-878fa2c027c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e357856-224a-42e6-8737-878fa2c027c9")) {                    Plotly.newPlot(                        "5e357856-224a-42e6-8737-878fa2c027c9",                        [{"customdata":[[1.69],[2.86],[3.24],[3.98]],"hovertemplate":"lat=%{lat}<br>lon=%{lon}<br>distance=%{marker.color}<extra></extra>","lat":[43.312167328205405,43.30971492706036,43.2762791618013,43.273828191657],"legendgroup":"","lon":[-8.392546563426139,-8.343226491469435,-8.395900525698163,-8.346609255749526],"marker":{"color":[1.69,2.86,3.24,3.98],"coloraxis":"coloraxis"},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"} ...

# %%
station = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LECO/input_files/LECOY2018Y2022.csv",
                          usecols =["time","wxcodes_o"],
                          parse_dates=["time"]).dropna().set_index("time")

pd.options.display.max_rows = 999
print("Weather frequencies\n")
station["wxcodes_o"].value_counts(normalize=True).map(lambda n: '{:.2%}'.format(n))
# Out:
# Weather frequencies
# M                  83.07%
# -RA                 4.35%
# BCFG                2.48%
# FG                  1.87%
# BR                  1.35%
# RA                  1.30%
# -DZ                 0.75%
# -RA BR              0.57%
# VCFG                0.55%
# SHRA                0.48%
# -SHRA               0.33%
# BR BCFG             0.33%
# PRFG                0.28%
# RA BR               0.24%
# DZ                  0.19%
# -DZ BR              0.13%
# -RA BCFG            0.13%
# VCSH                0.12%
# -RADZ               0.11%
# +RA                 0.09%
# FZFG                0.08%
# +SHRA               0.07%
# -DZ BCFG            0.06%
# VCTS                0.06%
# BCFG MIFG           0.05%
# MIFG                0.05%
# BR -DZ              0.04%
# RA BCFG             0.04%
# BCFG -DZ            0.04%
# -RA BR BCFG         0.04%
# RADZ                0.03%
# PRFG BCFG           0.03%
# -RA FG              0.03%
# DZ BR               0.03%
# SHGR                0.03%
# BR -RA              0.03%
# BCFG BR             0.02%
# BR DZ               0.02%
# +RA BR              0.02%
# BCFG -RA            0.02%
# SHRA BR             0.02%
# MIFG BCFG           0.01%
# BR PRFG             0.01%
# TSRA                0.01%
# -RA VCFG            0.01%
# DZ BCFG             0.01%
# -RA PRFG            0.01%
# -SHRA VCTS          0.01%
# BR VCFG             0.01%
# BR RA               0.01%
# BCFG VCFG           0.01%
# -RADZ BR            0.01%
# SHRA TS             0.01%
# VCTS -SHRA          0.01%
# SHRA VCTS           0.01%
# SHGS                0.01%
# TS                  0.01%
# BCFG PRFG           0.01%
# BCFG DZ             0.01%
# +TSRA               0.01%
# SHRAGS              0.01%
# RA FG               0.01%
# TS SHRA             0.01%
# FG -RA              0.01%
# -TSRA               0.01%
# -UP                 0.01%
# RA VCFG             0.01%
# RA BR BCFG          0.01%
# -SHRA VCSH          0.01%
# RADZ BR             0.01%
# SHRAGR              0.01%
# +RA FG              0.01%
# -RA VCSH            0.01%
# PRFG -DZ            0.01%
# FG -DZ              0.01%
# +SHGR               0.01%
# FG PRFG             0.00%
# -UP FG              0.00%
# TS +SHRA            0.00%
# -DZRA               0.00%
# -RA VCTS            0.00%
# +RA BCFG            0.00%
# FG BCFG             0.00%
# BCFG RA             0.00%
# +SHRAGS             0.00%
# PRFG BR             0.00%
# VCFG -RA            0.00%
# VCTS SHRA           0.00%
# VCTS BR             0.00%
# BR -RADZ            0.00%
# SHRA BCFG           0.00%
# VCTS -RA            0.00%
# -DZ PRFG            0.00%
# FU                  0.00%
# -RADZ FG            0.00%
# VCFG SHRA           0.00%
# +TSRA BCFG          0.00%
# +RA BR BCFG         0.00%
# UP                  0.00%
# DZ PRFG             0.00%
# -SHRA TS            0.00%
# PRFG MIFG           0.00%
# MIFG VCFG           0.00%
# -RA DZ              0.00%
# +SHRA VCTS          0.00%
# FG DZ               0.00%
# VCTS VCSH           0.00%
# RA TS BR            0.00%
# +SHRA BCFG          0.00%
# VCTS SHRA BR        0.00%
# -SHGR               0.00%
# -RA TS              0.00%
# VCFG BR             0.00%
# -RADZ BCFG          0.00%
# PRFG -RA            0.00%
# BR MIFG             0.00%
# BR RADZ             0.00%
# DZ FG               0.00%
# -DZ FG              0.00%
# VCFG VCSH           0.00%
# VCSH VCTS           0.00%
# RA TS               0.00%
# VCFG -DZ            0.00%
# SHRA BR TS          0.00%
# -TSRA BCFG          0.00%
# FZFG BCFG           0.00%
# BR -DZ BCFG         0.00%
# SHRA GS             0.00%
# -SHRA VCFG          0.00%
# RA BCFG VCFG        0.00%
# TS RA               0.00%
# RADZ BCFG           0.00%
# -RA TS BR           0.00%
# RA TS PRFG          0.00%
# -SHRA VCTS BCFG     0.00%
# +SHRA TS            0.00%
# RAGS                0.00%
# VCSH -SHRA          0.00%
# SHGSRA              0.00%
# VCFG DZ             0.00%
# -SHRAGS             0.00%
# +SHRA GS            0.00%
# SHRA FG             0.00%
# FG SHRA             0.00%
# VCTS FG             0.00%
# +SHRA TS PRFG       0.00%
# VCTS +SHRA BR       0.00%
# +GR                 0.00%
# TS VCSH             0.00%
# -SHGSRA             0.00%
# TS -SHRA            0.00%
# DZRA                0.00%
# -SHRA BCFG          0.00%
# -UP FZFG            0.00%
# SHRA GR             0.00%
# SHRA SHGR           0.00%
# +SHRAGR             0.00%
# -RA MIFG            0.00%
# VCSH -RA            0.00%
# -DZ BR BCFG         0.00%
# -DZ VCFG            0.00%
# Name: wxcodes_o, dtype: object

# %%
#label br/fg if weather code contains FG or BR

station["brfg_l"] = "No BR/FG"
mask = station['wxcodes_o'].str.contains("BR")
station.loc[mask,["brfg_l"]] = "BR/FG"
mask = station['wxcodes_o'].str.contains("FG")
station.loc[mask,["brfg_l"]] = "BR/FG"
pd.options.display.max_rows = 999

print(station.sample(50))
print("*****************************")
station["brfg_l"].value_counts(normalize=True).transform(lambda x: '{:,.0%}'.format(x))
# Out:
#                     wxcodes_o    brfg_l
# time
# 2022-08-05 16:30:00         M  No BR/FG
# 2019-04-23 08:00:00         M  No BR/FG
# 2019-04-28 21:00:00         M  No BR/FG
# 2021-08-25 15:30:00         M  No BR/FG
# 2021-05-09 14:00:00         M  No BR/FG
# 2022-05-22 22:30:00         M  No BR/FG
# 2018-01-01 05:00:00  24040.648438  ...  50.369999 -10.988547   0.2  0.000000
# ...                           ...  ...        ...        ...   ...       ...
# 2022-12-30 19:00:00  24038.054688  ...   0.000000   0.000000   0.2  0.320312
# 2022-12-30 20:00:00  24036.107422  ...   1.280000  -8.179551   0.3  0.500000
# 2022-12-30 21:00:00  24234.943359  ...   0.000000   0.000113   0.6  0.437500
# 2022-12-30 22:00:00  24234.662109  ...   0.656000  -9.782903   0.6  0.429688
# 2022-12-30 23:00:00  24036.123047  ...   1.680000  -2.866535   0.5  0.515625
#
#                      cfm3      cft3      HGT5003      HGT8503       T5003  \
# time
# 2018-01-01 01:00:00   0.0  0.200000  5563.714844  1548.354980  248.946930
# 2018-01-01 02:00:00   0.0  0.200000  5569.226074  1547.240967  249.484375
# 2018-01-01 03:00:00   0.0  0.300000  5577.497070  1547.338013  249.928879
# 2018-01-01 04:00:00   0.0  0.429688  5584.778809  1548.901001  250.126190
# 2018-01-01 05:00:00   0.0  0.200000  5587.893066  1549.415039  250.114441
# ...                   ...       ...          ...          ...         ...
# 2022-12-30 19:00:00   0.0  0.320312  5593.541016  1449.093994  256.560760
# 2022-12-30 20:00:00   0.0  0.500000  5598.160156  1454.644043  257.004120
# 2022-12-30 21:00:00   0.0  0.600000  5602.586914  1453.765991  257.113007
# 2022-12-30 22:00:00   0.0  0.600000  5604.122070  1452.741943  257.041443
# 2022-12-30 23:00:00   0.0  0.515625  5603.122070  1450.875000  257.380432
#
#                           T8503
# time
# 2018-01-01 01:00:00  273.993866
# 2018-01-01 02:00:00  273.890198
# 2018-01-01 03:00:00  273.821869
# 2018-01-01 04:00:00  273.762177
# 2018-01-01 05:00:00  274.289764
# ...                         ...
# 2022-12-30 19:00:00  282.030304
# 2022-12-30 20:00:00  281.343872
# 2022-12-30 21:00:00  281.831879
# 2022-12-30 22:00:00  281.463501
# 2022-12-30 23:00:00  281.020813
#
# [40829 rows x 101 columns]

# %%
import seaborn as sns
sns.set_theme(style="ticks")
df = df_all1k[["brfg_l","rh0","visibility0","cfl0"]].sample(100)
sns.pairplot(df, hue="brfg_l");
df["brfg_l"].value_counts()
# Out:
# No BR/FG    94
# BR/FG        6
# Name: brfg_l, dtype: int64

# %%
from sklearn.decomposition import PCA

df_pca = pd.DataFrame(PCA(n_components=3).fit_transform(df_all1k.iloc[:,1:]),
                                                        index =df_all1k.index)
df_pca["brfg_l"] = df_all1k.brfg_l
sns.pairplot(df_pca.sample(100), hue="brfg_l");

# %%
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyClassifier

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )


multiple_model = LazyClassifier(verbose =0, ignore_warnings = True,predictions=True)
models,predictions = multiple_model.fit(X_train,X_test,y_train,y_test)
# Out:
#  38%|███▊      | 11/29 [03:03<01:42,  5.72s/it]

# %%
models

# %% [markdown]
# **Meteorological model independent variables X**

# %%
df_all1k.iloc[:,1:].columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6796d3b8784> in <module>
# ----> 1 df_all1k.iloc[:,1:].columns
#
# NameError: name 'df_all1k' is not defined

# %% [markdown]
# **ML LGBMClassifier. Samples 10. Heidke Skill score. Significance level (alpha) = 0.01 for normality test of HSS samples**

# %%
from lightgbm.sklearn import LGBMClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from scipy.stats import shapiro

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
#X = df_all1k.iloc[:,1:]
X = 

# loop random
HSS = []
for t in range (0,10):

  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #train model
  ml_model = LGBMClassifier(n_estimators=200).fit(X_res,y_res)

  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS[t],2))

  #quality report
  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
# if p-value is lower than 5%, we can reject the null hypothesis of the normality of the dataset

print(pd.DataFrame(HSS,columns=["HSS"]).describe())

#sample less 5000
sta, p = shapiro(HSS)
print("\np value:",p)
#significance level alpha=0.01
alpha = 0.01
if p>alpha:
  print("Accept null hypothesis: normal distribution variable HSS in the samples")
else:
  print("Reject null Hypothesis. Alternative hypothesis variable HSS no normal distribution in samples")  

pd.DataFrame(HSS,columns=["HSS"]).hist();
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       429       257   686
# No BR/FG    583      6897  7480
# All        1012      7154  8166
# Heidke Skill Score: 0.45
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.423913  0.625364  0.505300   686.000000
# No BR/FG       0.964076  0.922059  0.942599  7480.000000
# accuracy       0.897134  0.897134  0.897134     0.897134
# macro avg      0.693995  0.773712  0.723950  8166.000000
# weighted avg   0.918699  0.897134  0.905863  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       409       263   672
# No BR/FG    640      6854  7494
# All        1049      7117  8166
# Heidke Skill Score: 0.42
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.389895  0.608631  0.475305   672.00000
# No BR/FG       0.963046  0.914598  0.938197  7494.00000
# accuracy       0.889420  0.889420  0.889420     0.88942
# macro avg      0.676471  0.761615  0.706751  8166.00000
# weighted avg   0.915880  0.889420  0.900105  8166.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       373       262   635
# No BR/FG    632      6899  7531
# All        1005      7161  8166
# Heidke Skill Score: 0.4
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.371144  0.587402  0.454878   635.000000
# No BR/FG       0.963413  0.916080  0.939151  7531.000000
# accuracy       0.890522  0.890522  0.890522     0.890522
# macro avg      0.667279  0.751741  0.697014  8166.000000
# weighted avg   0.917357  0.890522  0.901493  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       408       275   683
# No BR/FG    587      6896  7483
# All         995      7171  8166
# Heidke Skill Score: 0.43
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.410050  0.597365  0.486293   683.00000
# No BR/FG       0.961651  0.921556  0.941176  7483.00000
# accuracy       0.894440  0.894440  0.894440     0.89444
# macro avg      0.685851  0.759460  0.713735  8166.00000
# weighted avg   0.915515  0.894440  0.903130  8166.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       351       276   627
# No BR/FG    627      6912  7539
# All         978      7188  8166
# Heidke Skill Score: 0.38
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.358896  0.559809  0.437383   627.00000
# No BR/FG       0.961603  0.916832  0.938684  7539.00000
# accuracy       0.889420  0.889420  0.889420     0.88942
# macro avg      0.660249  0.738321  0.688034  8166.00000
# weighted avg   0.915326  0.889420  0.900193  8166.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       412       233   645
# No BR/FG    580      6941  7521
# All         992      7174  8166
# Heidke Skill Score: 0.45
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.415323  0.638760  0.503360   645.000000
# No BR/FG       0.967522  0.922883  0.944675  7521.000000
# accuracy       0.900441  0.900441  0.900441     0.900441
# macro avg      0.691422  0.780821  0.724017  8166.000000
# weighted avg   0.923906  0.900441  0.909817  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       382       279   661
# No BR/FG    573      6932  7505
# All         955      7211  8166
# Heidke Skill Score: 0.42
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.400000  0.577912  0.472772   661.000000
# No BR/FG       0.961309  0.923651  0.942104  7505.000000
# accuracy       0.895665  0.895665  0.895665     0.895665
# macro avg      0.680655  0.750782  0.707438  8166.000000
# weighted avg   0.915874  0.895665  0.904114  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       376       259   635
# No BR/FG    614      6917  7531
# All         990      7176  8166
# Heidke Skill Score: 0.41
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.379798  0.592126  0.462769   635.000000
# No BR/FG       0.963907  0.918470  0.940641  7531.000000
# accuracy       0.893093  0.893093  0.893093     0.893093
# macro avg      0.671853  0.755298  0.701705  8166.000000
# weighted avg   0.918486  0.893093  0.903481  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       384       247   631
# No BR/FG    600      6935  7535
# All         984      7182  8166
# Heidke Skill Score: 0.42
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.390244  0.608558  0.475542   631.000000
# No BR/FG       0.965608  0.920372  0.942448  7535.000000
# accuracy       0.896277  0.896277  0.896277     0.896277
# macro avg      0.677926  0.764465  0.708995  8166.000000
# weighted avg   0.921149  0.896277  0.906369  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       376       284   660
# No BR/FG    587      6919  7506
# All         963      7203  8166
# Heidke Skill Score: 0.41
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.390447  0.569697  0.463339   660.000000
# No BR/FG       0.960572  0.921796  0.940785  7506.000000
# accuracy       0.893338  0.893338  0.893338     0.893338
# macro avg      0.675509  0.745746  0.702062  8166.000000
# weighted avg   0.914493  0.893338  0.902196  8166.000000
#
# HSS stadistics
#              HSS
# count  10.000000
# mean    0.417528
# std     0.022229
# min     0.379302
# 25%     0.406440
# 50%     0.416897
# 75%     0.427552
# max     0.450784
#
# p value: 0.7257279753684998
# Accept null hypothesis: normal distribution variable HSS in the samples

# %% [markdown]
# **Add time features**

# %%
df_all1k["hour"] = df_all1k.index.hour
df_all1k["month"] = df_all1k.index.month
df_all1k["dayofyear"] = df_all1k.index.dayofyear
df_all1k["weekofyear"] = df_all1k.index.isocalendar().week.astype(int)

# %%
df_all1k.iloc[:,1:].columns
# Out:
# Index(['dir0', 'snow_prec0', 'snowlevel0', 'mod0', 'wind_gust0', 'mslp0',
#        'temp0', 'rh0', 'visibility0', 'lhflx0',
#        ...
#        'cfm3', 'cft3', 'HGT5003', 'HGT8503', 'T5003', 'T8503', 'hour', 'month',
#        'dayofyear', 'weekofyear'],
#       dtype='object', length=104)

# %%
# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

multiple_model = LazyClassifier(verbose =0, ignore_warnings = True,predictions=True)
models,predictions = multiple_model.fit(X_train,X_test,y_train,y_test)
models
# Out:
# 100%|██████████| 29/29 [00:58<00:00,  2.01s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LabelPropagation                   0.88               0.81    None      0.88
# LabelSpreading                     0.88               0.81    None      0.88
# ExtraTreesClassifier               0.90               0.79    None      0.90
# LGBMClassifier                     0.90               0.79    None      0.89
# BaggingClassifier                  0.88               0.78    None      0.88
# RandomForestClassifier             0.90               0.78    None      0.89
# KNeighborsClassifier               0.88               0.77    None      0.88
# Perceptron                         0.83               0.75    None      0.83
# DecisionTreeClassifier             0.85               0.75    None      0.85
# ExtraTreeClassifier                0.84               0.75    None      0.84
# QuadraticDiscriminantAnalysis      0.76               0.75    None      0.78
# GaussianNB                         0.76               0.74    None      0.79
# BernoulliNB                        0.75               0.74    None      0.77
# NearestCentroid                    0.75               0.74    None      0.78
# SGDClassifier                      0.85               0.73    None      0.85
# XGBClassifier                      0.88               0.73    None      0.87
# AdaBoostClassifier                 0.87               0.73    None      0.86
# LogisticRegression                 0.86               0.71    None      0.85
# CalibratedClassifierCV             0.86               0.71    None      0.85
# LinearDiscriminantAnalysis         0.86               0.70    None      0.85
# SVC                                0.87               0.70    None      0.86
# LinearSVC                          0.86               0.70    None      0.85
# PassiveAggressiveClassifier        0.83               0.69    None      0.82
# RidgeClassifierCV                  0.86               0.67    None      0.84
# RidgeClassifier                    0.86               0.66    None      0.84
# DummyClassifier                    0.82               0.50    None      0.74
#
#                                Time Taken
# Model
# LabelPropagation                     7.42
# LabelSpreading                      11.21
# ExtraTreesClassifier                 1.45
# LGBMClassifier                       0.96
# BaggingClassifier                    4.67
# RandomForestClassifier               6.96
# KNeighborsClassifier                 1.20
# Perceptron                           0.19
# DecisionTreeClassifier               0.81
# ExtraTreeClassifier                  0.08
# QuadraticDiscriminantAnalysis        0.28
# GaussianNB                           0.08
# BernoulliNB                          0.12
# NearestCentroid                      0.19
# SGDClassifier                        0.21
# XGBClassifier                        2.69
# AdaBoostClassifier                   3.98
# LogisticRegression                   0.69
# CalibratedClassifierCV               6.03
# LinearDiscriminantAnalysis           0.23
# SVC                                  5.71
# LinearSVC                            2.36
# PassiveAggressiveClassifier          0.20
# RidgeClassifierCV                    0.25
# RidgeClassifier                      0.12
# DummyClassifier                      0.07

# %%
from lightgbm.sklearn import LGBMClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.tree import ExtraTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from scipy.stats import shapiro

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]
#X = df_all1k[["rh0","visibility0","mod0","rh1","visibility1","mod1",'hour', 'month','dayofyear']]

# loop random
HSS_a = []
for t in range (0,10):

  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #train model
  ml_model = LGBMClassifier(n_estimators=200).fit(X_res,y_res)
  #ml_model = ExtraTreeClassifier().fit(X_res,y_res)
  #ml_model = Perceptron().fit(X_res,y_res)
  #ml_model = RandomForestClassifier().fit(X_res,y_res)

  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_a.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_a[t],2))

  #quality report
  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
# if p-value is lower than 1%, we can reject the null hypothesis of the normality of the dataset

print(pd.DataFrame(HSS_a,columns=["HSS"]).describe())

#sample less 5000
sta, p = shapiro(HSS_a)
print("\np value:",p)

#significance level alpha=0.01
alpha = 0.01
if p>alpha:
  print("Accept null Hypothesis: normal distribution variable HSS in the samples")
else:
  print("Reject null Hypothesis. Alternative hypothesis variable HSS no normal distribution in samples")  

pd.DataFrame(HSS_a,columns=["HSS_a"]).hist();
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       424       262   686
# No BR/FG    466      7014  7480
# All         890      7276  8166
# Heidke Skill Score: 0.49
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.476404  0.618076  0.538071   686.00000
# No BR/FG       0.963991  0.937701  0.950664  7480.00000
# accuracy       0.910850  0.910850  0.910850     0.91085
# macro avg      0.720198  0.777888  0.744368  8166.00000
# weighted avg   0.923031  0.910850  0.916003  8166.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       415       257   672
# No BR/FG    490      7004  7494
# All         905      7261  8166
# Heidke Skill Score: 0.48
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.458564  0.617560  0.526316   672.000000
# No BR/FG       0.964605  0.934614  0.949373  7494.000000
# accuracy       0.908523  0.908523  0.908523     0.908523
# macro avg      0.711584  0.776087  0.737844  8166.000000
# weighted avg   0.922962  0.908523  0.914559  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       387       248   635
# No BR/FG    521      7010  7531
# All         908      7258  8166
# Heidke Skill Score: 0.45
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.426211  0.609449  0.501620   635.000000
# No BR/FG       0.965831  0.930819  0.948002  7531.000000
# accuracy       0.905829  0.905829  0.905829     0.905829
# macro avg      0.696021  0.770134  0.724811  8166.000000
# weighted avg   0.923869  0.905829  0.913291  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       406       277   683
# No BR/FG    482      7001  7483
# All         888      7278  8166
# Heidke Skill Score: 0.47
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.457207  0.594436  0.516868   683.000000
# No BR/FG       0.961940  0.935587  0.948581  7483.000000
# accuracy       0.907054  0.907054  0.907054     0.907054
# macro avg      0.709574  0.765012  0.732724  8166.000000
# weighted avg   0.919724  0.907054  0.912473  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       374       253   627
# No BR/FG    464      7075  7539
# All         838      7328  8166
# Heidke Skill Score: 0.46
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.446301  0.596491  0.510580   627.000000
# No BR/FG       0.965475  0.938453  0.951772  7539.000000
# accuracy       0.912197  0.912197  0.912197     0.912197
# macro avg      0.705888  0.767472  0.731176  8166.000000
# weighted avg   0.925612  0.912197  0.917897  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       420       225   645
# No BR/FG    480      7041  7521
# All         900      7266  8166
# Heidke Skill Score: 0.5
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.466667  0.651163  0.543689   645.000000
# No BR/FG       0.969034  0.936179  0.952323  7521.000000
# accuracy       0.913666  0.913666  0.913666     0.913666
# macro avg      0.717850  0.793671  0.748006  8166.000000
# weighted avg   0.929354  0.913666  0.920047  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       389       272   661
# No BR/FG    442      7063  7505
# All         831      7335  8166
# Heidke Skill Score: 0.47
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.468111  0.588502  0.521448   661.000000
# No BR/FG       0.962918  0.941106  0.951887  7505.000000
# accuracy       0.912564  0.912564  0.912564     0.912564
# macro avg      0.715514  0.764804  0.736667  8166.000000
# weighted avg   0.922865  0.912564  0.917045  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       373       262   635
# No BR/FG    471      7060  7531
# All         844      7322  8166
# Heidke Skill Score: 0.46
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.441943  0.587402  0.504395   635.000000
# No BR/FG       0.964217  0.937459  0.950650  7531.000000
# accuracy       0.910238  0.910238  0.910238     0.910238
# macro avg      0.703080  0.762430  0.727522  8166.000000
# weighted avg   0.923605  0.910238  0.915948  8166.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       374       257   631
# No BR/FG    467      7068  7535
# All         841      7325  8166
# Heidke Skill Score: 0.46
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.444709  0.592710  0.508152   631.00000
# No BR/FG       0.964915  0.938023  0.951279  7535.00000
# accuracy       0.911340  0.911340  0.911340     0.91134
# macro avg      0.704812  0.765366  0.729715  8166.00000
# weighted avg   0.924718  0.911340  0.917038  8166.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       393       267   660
# No BR/FG    445      7061  7506
# All         838      7328  8166
# Heidke Skill Score: 0.48
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.468974  0.595455  0.524700   660.000000
# No BR/FG       0.963564  0.940714  0.952002  7506.000000
# accuracy       0.912809  0.912809  0.912809     0.912809
# macro avg      0.716269  0.768084  0.738351  8166.000000
# weighted avg   0.923590  0.912809  0.917466  8166.000000
#
# HSS stadistics
#              HSS
# count  10.000000
# mean    0.471339
# std     0.014622
# min     0.451414
# 25%     0.461251
# 50%     0.470218
# 75%     0.477312
# max     0.497443
#
# p value: 0.8072018623352051
# Accept null Hypothesis: normal distribution variable HSS in the samples

# %% [markdown]
# **Test association between observed variable and machine learning forecast (Pearson’s chi square test). Significance level (alpha) = 0.01**

# %%
from scipy.stats import chi2_contingency

print("Last confusion matrix\n")
print(cm.iloc[0:2,0:2])

#stadistic(sta), pvalue (p), degrees of freedom (dof) and expected values (exp)
sta, p, dof, exp = chi2_contingency(cm.iloc[0:2,0:2])

#degrees of freedoom (rows-1)*(columns-1) to test associationbetween two variables
alpha = 0.01
print('\np-value:',p)
print('Significance level:',alpha)
print('Degres of of freedom: ',dof)
print("Stadistic",sta)

if p<=alpha:
    print("Reject H0,There is an association between machine learning forecast and observed values")
else:
    print("Retain H0,There is no association between machine learning forecast and observed values")
# Out:
# Last confusion matrix
#
# col_0     BR/FG  No BR/FG
# brfg_l
# BR/FG       393       267
# No BR/FG    445      7061
#
# p-value: 0.0
# Significance level: 0.01
# Degres of of freedom:  1
# Stadistic 1887.9870190714894
# Reject H0,There is an association between machine learning forecast and observed values

# %% [markdown]
# **T test two related samples. This is a test for the null hypothesis that two related samples have identical HSS means. Alternative hypothesis the mean of the distribution underlying the sample without time variables is less than the mean of the distribution underlying the sample with time variables. Significance level (alpha) = 0.01**

# %%
from scipy import stats

alpha = 0.01
sta, p_value = stats.ttest_rel(HSS, HSS_a, alternative="less")

print("\nmeans without time variables:", np.round(HSS,2))
print("\nmeans with time variables:", np.round(HSS_a,2))

print("\nalpha: ",alpha)

print("\np_value point: ",p_value)
if p_value < alpha:    
    print("\nwe are rejecting null hypothesis  H0: HHS mean without time variables = HSS mean with time variables")
    print("\nwe are accepting alternative hypothesis: the HSS mean of the sample without time variables inputs is less than the HSS mean of the sample with time variables inputs")
else:
    print("\nwe are accepting null hypothesis:  H0: HSS mean without time variables = HSS mean with time variables ")
# Out:
# means without time variables: [0.45 0.42 0.4  0.43 0.38 0.45 0.42 0.41 0.42 0.41]
#
# means with time variables: [0.49 0.48 0.45 0.47 0.46 0.5  0.47 0.46 0.46 0.48]
#
# alpha:  0.01
#
# p_value point:  6.428033512770454e-07
#
# we are rejecting null hypothesis  H0: HHS mean without time variables = HSS mean with time variables
#
# we are accepting alternative hypothesis: the HSS mean of the sample without time variables inputs is less than the HSS mean of the sample with time variables inputs

# %%
import pickle
from sklearn.pipeline import Pipeline

estimators = [('ml_model', ml_model)]
pipe = Pipeline(estimators)
print(pipe)
al_file={"x_var":X.columns,"coor":coor,"pipe":pipe}
pickle.dump(al_file, open("brfg_LECO_d0.al", 'wb'))
# Out:
# Pipeline(steps=[('ml_model', LGBMClassifier(n_estimators=200))])

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.1

# %% [markdown]
# **Best algorithm too heavy to upload in github!!**

# %%
df_all1k.iloc[:,1:].columns
# Out:
# Index(['dir0', 'snow_prec0', 'snowlevel0', 'mod0', 'wind_gust0', 'mslp0',
#        'temp0', 'rh0', 'visibility0', 'lhflx0',
#        ...
#        'cfm3', 'cft3', 'HGT5003', 'HGT8503', 'T5003', 'T8503', 'hour', 'month',
#        'dayofyear', 'weekofyear'],
#       dtype='object', length=104)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

# loop random
HSS_b = []
for t in range (0,10):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  ml_model = ExtraTreesClassifier(n_estimators=300).fit(X_res,y_res)

  #Confussion matrix

  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_b.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_b[t],2))

  #quality report

  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
pd.DataFrame(HSS_b,columns=["HSS"]).describe()
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       333       173   506
# No BR/FG    200      5419  5619
# All         533      5592  6125
# Heidke Skill Score: 0.61
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.624765  0.658103  0.641001   506.000000
# No BR/FG       0.969063  0.964406  0.966729  5619.000000
# accuracy       0.939102  0.939102  0.939102     0.939102
# macro avg      0.796914  0.811255  0.803865  6125.000000
# weighted avg   0.940620  0.939102  0.939820  6125.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       325       196   521
# No BR/FG    204      5400  5604
# All         529      5596  6125
# Heidke Skill Score: 0.58
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.614367  0.623800  0.619048   521.000000
# No BR/FG       0.964975  0.963597  0.964286  5604.000000
# accuracy       0.934694  0.934694  0.934694     0.934694
# macro avg      0.789671  0.793699  0.791667  6125.000000
# weighted avg   0.935152  0.934694  0.934919  6125.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       309       178   487
# No BR/FG    187      5451  5638
# All         496      5629  6125
# Heidke Skill Score: 0.6
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.622984  0.634497  0.628688   487.000000
# No BR/FG       0.968378  0.966832  0.967605  5638.000000
# accuracy       0.940408  0.940408  0.940408     0.940408
# macro avg      0.795681  0.800665  0.798146  6125.000000
# weighted avg   0.940916  0.940408  0.940657  6125.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       330       173   503
# No BR/FG    216      5406  5622
# All         546      5579  6125
# Heidke Skill Score: 0.59
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.604396  0.656064  0.629171   503.00000
# No BR/FG       0.968991  0.961580  0.965271  5622.00000
# accuracy       0.936490  0.936490  0.936490     0.93649
# macro avg      0.786693  0.808822  0.797221  6125.00000
# weighted avg   0.939049  0.936490  0.937670  6125.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       335       179   514
# No BR/FG    197      5414  5611
# All         532      5593  6125
# Heidke Skill Score: 0.61
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.629699  0.651751  0.640535   514.000000
# No BR/FG       0.967996  0.964890  0.966441  5611.000000
# accuracy       0.938612  0.938612  0.938612     0.938612
# macro avg      0.798847  0.808321  0.803488  6125.000000
# weighted avg   0.939606  0.938612  0.939091  6125.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       307       190   497
# No BR/FG    198      5430  5628
# All         505      5620  6125
# Heidke Skill Score: 0.58
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.607921  0.617706  0.612774   497.000000
# No BR/FG       0.966192  0.964819  0.965505  5628.000000
# accuracy       0.936653  0.936653  0.936653     0.936653
# macro avg      0.787056  0.791263  0.789140  6125.000000
# weighted avg   0.937121  0.936653  0.936883  6125.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       299       180   479
# No BR/FG    193      5453  5646
# All         492      5633  6125
# Heidke Skill Score: 0.58
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.607724  0.624217  0.615860   479.000000
# No BR/FG       0.968045  0.965817  0.966930  5646.000000
# accuracy       0.939102  0.939102  0.939102     0.939102
# macro avg      0.787885  0.795017  0.791395  6125.000000
# weighted avg   0.939867  0.939102  0.939475  6125.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       313       183   496
# No BR/FG    153      5476  5629
# All         466      5659  6125
# Heidke Skill Score: 0.62
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.671674  0.631048  0.650728   496.000000
# No BR/FG       0.967662  0.972819  0.970234  5629.000000
# accuracy       0.945143  0.945143  0.945143     0.945143
# macro avg      0.819668  0.801934  0.810481  6125.000000
# weighted avg   0.943693  0.945143  0.944360  6125.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       317       163   480
# No BR/FG    177      5468  5645
# All         494      5631  6125
# Heidke Skill Score: 0.62
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.641700  0.660417  0.650924   480.00000
# No BR/FG       0.971053  0.968645  0.969847  5645.00000
# accuracy       0.944490  0.944490  0.944490     0.94449
# macro avg      0.806377  0.814531  0.810386  6125.00000
# weighted avg   0.945243  0.944490  0.944854  6125.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       315       181   496
# No BR/FG    172      5457  5629
# All         487      5638  6125
# Heidke Skill Score: 0.61
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.646817  0.635081  0.640895   496.000000
# No BR/FG       0.967896  0.969444  0.968670  5629.000000
# accuracy       0.942367  0.942367  0.942367     0.942367
# macro avg      0.807357  0.802262  0.804782  6125.000000
# weighted avg   0.941896  0.942367  0.942127  6125.000000
#
# HSS stadistics
#              HSS
# count  10.000000
# mean    0.600129
# std     0.015499
# min     0.578282
# 25%     0.586128
# 50%     0.601641
# 75%     0.609114
# max     0.620993

# %% [markdown]
# **T test two related samples. This is a test for the null hypothesis that two related samples have identical HSS means. Alternative hypothesis the mean of the distribution underlying the sample without time variables is less than the mean of the distribution underlying the sample with time variables. Significance level (alpha) = 0.01**

# %%
from scipy import stats

alpha = 0.01
sta, p_value = stats.ttest_rel(HSS_a, HSS_b, alternative="less")

print("\nHSS LGBMClassifier:", np.round(HSS_a,2))
print("\nHSS ExtraTreesClassifier:", np.round(HSS_b,2))

print("\nalpha: ",alpha)

print("\np_value point: ",p_value)
if p_value < alpha:    
    print("\nwe are rejecting null hypothesis  H0: HHS mean ExtraTreesClassifier = HSS mean with LGBMClassifier")
    print("\nwe are accepting alternative hypothesis: the HSS mean of the sample LGBMClassifier is less than the HSS mean of the sample with ExtraTreesClassifier")
else:
    print("\nwe are accepting null hypothesis:  H0: HSS mean LGBMClassifier = HSS mean with ExtraTreesClassifier")
# Out:
# HSS LGBMClassifier: [0.49 0.48 0.45 0.47 0.46 0.5  0.47 0.46 0.46 0.48]
#
# HSS ExtraTreesClassifier: [0.61 0.58 0.6  0.59 0.61 0.58 0.58 0.62 0.62 0.61]
#
# alpha:  0.01
#
# p_value point:  3.8973080539776874e-08
#
# we are rejecting null hypothesis  H0: HHS mean ExtraTreesClassifier = HSS mean with LGBMClassifier
#
# we are accepting alternative hypothesis: the HSS mean of the sample LGBMClassifier is less than the HSS mean of the sample with ExtraTreesClassifier

# %% [markdown]
# **PCA components**

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

# loop random
HSS_pca = []
for t in range (0,10):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #scaler
  sc = StandardScaler().fit(X_res)
  X_sc = sc.transform(X_res)

  #PCA
  n_components = len(X.columns)
  pca = PCA(n_components).fit(X_sc)
  X_pca = pca.transform(X_sc)

  #machine learning model
  #ml_model = ExtraTreesClassifier(n_estimators=150).fit(X_pca,y_res)
  ml_model = MLPClassifier(hidden_layer_sizes=(100,50,10)).fit(X_pca,y_res)
  
  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  y_pca = pca.transform(sc.transform(X_test))
  cm = pd.crosstab(y_test, ml_model.predict(y_pca),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_pca.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_pca[t],2))

  #quality report

  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(y_pca),output_dict=True)).T)

print("\nHSS stadistics")
pd.DataFrame(HSS_pca,columns=["HSS_pca"]).describe()
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       287       150   437
# No BR/FG    179      1855  2034
# All         466      2005  2471
# Heidke Skill Score: 0.55
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.615880  0.656751  0.635659   437.000000
# No BR/FG       0.925187  0.911996  0.918544  2034.000000
# accuracy       0.866856  0.866856  0.866856     0.866856
# macro avg      0.770533  0.784373  0.777102  2471.000000
# weighted avg   0.870486  0.866856  0.868516  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       288       173   461
# No BR/FG    208      1802  2010
# All         496      1975  2471
# Heidke Skill Score: 0.51
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.580645  0.624729  0.601881   461.000000
# No BR/FG       0.912405  0.896517  0.904391  2010.000000
# accuracy       0.845811  0.845811  0.845811     0.845811
# macro avg      0.746525  0.760623  0.753136  2471.000000
# weighted avg   0.850511  0.845811  0.847954  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       348       119   467
# No BR/FG    214      1790  2004
# All         562      1909  2471
# Heidke Skill Score: 0.59
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.619217  0.745182  0.676385   467.000000
# No BR/FG       0.937664  0.893214  0.914899  2004.000000
# accuracy       0.865237  0.865237  0.865237     0.865237
# macro avg      0.778440  0.819198  0.795642  2471.000000
# weighted avg   0.877480  0.865237  0.869822  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       300       149   449
# No BR/FG    139      1883  2022
# All         439      2032  2471
# Heidke Skill Score: 0.6
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.683371  0.668151  0.675676   449.000000
# No BR/FG       0.926673  0.931256  0.928959  2022.000000
# accuracy       0.883448  0.883448  0.883448     0.883448
# macro avg      0.805022  0.799704  0.802317  2471.000000
# weighted avg   0.882463  0.883448  0.882935  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       273       176   449
# No BR/FG    136      1886  2022
# All         409      2062  2471
# Heidke Skill Score: 0.56
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.667482  0.608018  0.636364   449.000000
# No BR/FG       0.914646  0.932740  0.923604  2022.000000
# accuracy       0.873735  0.873735  0.873735     0.873735
# macro avg      0.791064  0.770379  0.779984  2471.000000
# weighted avg   0.869734  0.873735  0.871410  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       295       164   459
# No BR/FG    148      1864  2012
# All         443      2028  2471
# Heidke Skill Score: 0.58
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.665914  0.642702  0.654102   459.000000
# No BR/FG       0.919132  0.926441  0.922772  2012.000000
# accuracy       0.873735  0.873735  0.873735     0.873735
# macro avg      0.792523  0.784571  0.788437  2471.000000
# weighted avg   0.872096  0.873735  0.872865  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       337       154   491
# No BR/FG    176      1804  1980
# All         513      1958  2471
# Heidke Skill Score: 0.59
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.656920  0.686354  0.671315   491.000000
# No BR/FG       0.921348  0.911111  0.916201  1980.000000
# accuracy       0.866451  0.866451  0.866451     0.866451
# macro avg      0.789134  0.798733  0.793758  2471.000000
# weighted avg   0.868805  0.866451  0.867541  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       308       178   486
# No BR/FG    155      1830  1985
# All         463      2008  2471
# Heidke Skill Score: 0.57
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.665227  0.633745  0.649104   486.000000
# No BR/FG       0.911355  0.921914  0.916604  1985.000000
# accuracy       0.865237  0.865237  0.865237     0.865237
# macro avg      0.788291  0.777830  0.782854  2471.000000
# weighted avg   0.862946  0.865237  0.863992  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       280       166   446
# No BR/FG    179      1846  2025
# All         459      2012  2471
# Heidke Skill Score: 0.53
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.610022  0.627803  0.618785   446.00000
# No BR/FG       0.917495  0.911605  0.914541  2025.00000
# accuracy       0.860380  0.860380  0.860380     0.86038
# macro avg      0.763758  0.769704  0.766663  2471.00000
# weighted avg   0.861998  0.860380  0.861158  2471.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       285       165   450
# No BR/FG    164      1857  2021
# All         449      2022  2471
# Heidke Skill Score: 0.55
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.634744  0.633333  0.634038   450.000000
# No BR/FG       0.918398  0.918852  0.918625  2021.000000
# accuracy       0.866856  0.866856  0.866856     0.866856
# macro avg      0.776571  0.776093  0.776331  2471.000000
# weighted avg   0.866741  0.866856  0.866798  2471.000000
#
# HSS stadistics
#          HSS_pca
# count  10.000000
# mean    0.563400
# std     0.029173
# min     0.506431
# 25%     0.553074
# 50%     0.562969
# 75%     0.584901
# max     0.604646
