# %%
# !pip install -r "/content/drive/MyDrive/Colab Notebooks/LEVX_1km/requirements.txt"

# %%
# !pip install lazypredict

# %%
import plotly.express as px
import pandas as pd
import numpy as np
coor=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LECO/input_files/distan_lat43.302lon-8.377p4R4Km.csv")
px.set_mapbox_access_token("pk.eyJ1IjoiZ3JhbmFudHVpbiIsImEiOiJja3B4dGU4OTkwMTFmMm9ycnNhMjJvaGJqIn0.VWzx_PkD9A5cSUVsn_ijCA")
px.scatter_mapbox(coor, hover_data=['distance'],lat='lat', lon='lon',color='distance', title="Nearest points",
                           color_continuous_scale=px.colors.cyclical.IceFire,)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="69af6607-a55d-48b1-a79a-1d530e11625a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69af6607-a55d-48b1-a79a-1d530e11625a")) {                    Plotly.newPlot(                        "69af6607-a55d-48b1-a79a-1d530e11625a",                        [{"customdata":[[1.69],[2.86],[3.24],[3.98]],"hovertemplate":"lat=%{lat}<br>lon=%{lon}<br>distance=%{marker.color}<extra></extra>","lat":[43.312167328205405,43.30971492706036,43.2762791618013,43.273828191657],"legendgroup":"","lon":[-8.392546563426139,-8.343226491469435,-8.395900525698163,-8.346609255749526],"marker":{"color":[1.69,2.86,3.24,3.98],"coloraxis":"coloraxis"},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"} ...

# %%
station = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LECO/input_files/LECOY2018Y2022.csv",
                          usecols =["time","wxcodes_o"],
                          parse_dates=["time"]).dropna().set_index("time")

pd.options.display.max_rows = 999
print("Weather frequencies\n")
station["wxcodes_o"].value_counts(normalize=True).map(lambda n: '{:.2%}'.format(n))
# Out:
# Weather frequencies
# M                  83.07%
# -RA                 4.35%
# BCFG                2.48%
# FG                  1.87%
# BR                  1.35%
# RA                  1.30%
# -DZ                 0.75%
# -RA BR              0.57%
# VCFG                0.55%
# SHRA                0.48%
# -SHRA               0.33%
# BR BCFG             0.33%
# PRFG                0.28%
# RA BR               0.24%
# DZ                  0.19%
# -DZ BR              0.13%
# -RA BCFG            0.13%
# VCSH                0.12%
# -RADZ               0.11%
# +RA                 0.09%
# FZFG                0.08%
# +SHRA               0.07%
# -DZ BCFG            0.06%
# VCTS                0.06%
# BCFG MIFG           0.05%
# MIFG                0.05%
# BR -DZ              0.04%
# RA BCFG             0.04%
# BCFG -DZ            0.04%
# -RA BR BCFG         0.04%
# RADZ                0.03%
# PRFG BCFG           0.03%
# -RA FG              0.03%
# DZ BR               0.03%
# SHGR                0.03%
# BR -RA              0.03%
# BCFG BR             0.02%
# BR DZ               0.02%
# +RA BR              0.02%
# BCFG -RA            0.02%
# SHRA BR             0.02%
# MIFG BCFG           0.01%
# BR PRFG             0.01%
# TSRA                0.01%
# -RA VCFG            0.01%
# DZ BCFG             0.01%
# -RA PRFG            0.01%
# -SHRA VCTS          0.01%
# BR VCFG             0.01%
# BR RA               0.01%
# BCFG VCFG           0.01%
# -RADZ BR            0.01%
# SHRA TS             0.01%
# VCTS -SHRA          0.01%
# SHRA VCTS           0.01%
# SHGS                0.01%
# TS                  0.01%
# BCFG PRFG           0.01%
# BCFG DZ             0.01%
# +TSRA               0.01%
# SHRAGS              0.01%
# RA FG               0.01%
# TS SHRA             0.01%
# FG -RA              0.01%
# -TSRA               0.01%
# -UP                 0.01%
# RA VCFG             0.01%
# RA BR BCFG          0.01%
# -SHRA VCSH          0.01%
# RADZ BR             0.01%
# SHRAGR              0.01%
# +RA FG              0.01%
# -RA VCSH            0.01%
# PRFG -DZ            0.01%
# FG -DZ              0.01%
# +SHGR               0.01%
# FG PRFG             0.00%
# -UP FG              0.00%
# TS +SHRA            0.00%
# -DZRA               0.00%
# -RA VCTS            0.00%
# +RA BCFG            0.00%
# FG BCFG             0.00%
# BCFG RA             0.00%
# +SHRAGS             0.00%
# PRFG BR             0.00%
# VCFG -RA            0.00%
# VCTS SHRA           0.00%
# VCTS BR             0.00%
# BR -RADZ            0.00%
# SHRA BCFG           0.00%
# VCTS -RA            0.00%
# -DZ PRFG            0.00%
# FU                  0.00%
# -RADZ FG            0.00%
# VCFG SHRA           0.00%
# +TSRA BCFG          0.00%
# +RA BR BCFG         0.00%
# UP                  0.00%
# DZ PRFG             0.00%
# -SHRA TS            0.00%
# PRFG MIFG           0.00%
# MIFG VCFG           0.00%
# -RA DZ              0.00%
# +SHRA VCTS          0.00%
# FG DZ               0.00%
# VCTS VCSH           0.00%
# RA TS BR            0.00%
# +SHRA BCFG          0.00%
# VCTS SHRA BR        0.00%
# -SHGR               0.00%
# -RA TS              0.00%
# VCFG BR             0.00%
# -RADZ BCFG          0.00%
# PRFG -RA            0.00%
# BR MIFG             0.00%
# BR RADZ             0.00%
# DZ FG               0.00%
# -DZ FG              0.00%
# VCFG VCSH           0.00%
# VCSH VCTS           0.00%
# RA TS               0.00%
# VCFG -DZ            0.00%
# SHRA BR TS          0.00%
# -TSRA BCFG          0.00%
# FZFG BCFG           0.00%
# BR -DZ BCFG         0.00%
# SHRA GS             0.00%
# -SHRA VCFG          0.00%
# RA BCFG VCFG        0.00%
# TS RA               0.00%
# RADZ BCFG           0.00%
# -RA TS BR           0.00%
# RA TS PRFG          0.00%
# -SHRA VCTS BCFG     0.00%
# +SHRA TS            0.00%
# RAGS                0.00%
# VCSH -SHRA          0.00%
# SHGSRA              0.00%
# VCFG DZ             0.00%
# -SHRAGS             0.00%
# +SHRA GS            0.00%
# SHRA FG             0.00%
# FG SHRA             0.00%
# VCTS FG             0.00%
# +SHRA TS PRFG       0.00%
# VCTS +SHRA BR       0.00%
# +GR                 0.00%
# TS VCSH             0.00%
# -SHGSRA             0.00%
# TS -SHRA            0.00%
# DZRA                0.00%
# -SHRA BCFG          0.00%
# -UP FZFG            0.00%
# SHRA GR             0.00%
# SHRA SHGR           0.00%
# +SHRAGR             0.00%
# -RA MIFG            0.00%
# VCSH -RA            0.00%
# -DZ BR BCFG         0.00%
# -DZ VCFG            0.00%
# Name: wxcodes_o, dtype: object

# %%
#label br/fg if weather code contains FG or BR

station["brfg_l"] = "No BR/FG"
mask = station['wxcodes_o'].str.contains("BR")
station.loc[mask,["brfg_l"]] = "BR/FG"
mask = station['wxcodes_o'].str.contains("FG")
station.loc[mask,["brfg_l"]] = "BR/FG"
pd.options.display.max_rows = 999

print(station.sample(50))
print("*****************************")
station["brfg_l"].value_counts(normalize=True).transform(lambda x: '{:,.0%}'.format(x))
# Out:
#                      wxcodes_o    brfg_l
# time
# 2019-04-22 16:30:00          M  No BR/FG
# 2022-06-17 02:00:00          M  No BR/FG
# 2022-10-01 12:00:00          M  No BR/FG
# 2018-09-07 21:00:00          M  No BR/FG
# 2021-09-14 21:30:00          M  No BR/FG
# 2021-01-14 22:24:00         FG     BR/FG
# 2018-09-14 17:00:00          M  No BR/FG
# 2021-08-25 08:30:00          M  No BR/FG
# 2020-01-12 20:30:00          M  No BR/FG
# 2021-08-30 20:00:00          M  No BR/FG
# 2020-04-02 02:30:00          M  No BR/FG
# 2022-12-30 23:00:00  24234.580078  ...   8.80 -7.387965  0.100000  0.570312
#
#                          cfm3      cft3      HGT5003      HGT8503       T5003  \
# time
# 2018-01-02 00:00:00  0.000000  0.089097  5693.558105  1584.069946  254.864120
# 2018-01-02 01:00:00  0.200000  0.500000  5691.708008  1580.140015  254.976685
# 2018-01-02 02:00:00  0.343750  0.343750  5690.079102  1577.298950  255.064560
# 2018-01-02 03:00:00  0.734375  0.734375  5690.610840  1572.140015  254.839066
# 2018-01-02 04:00:00  0.515625  0.656250  5690.393066  1574.123047  255.089691
# ...                       ...       ...          ...          ...         ...
# 2022-12-30 19:00:00  0.000000  0.523438  5601.289062  1451.552979  256.711487
# 2022-12-30 20:00:00  0.000000  0.468750  5604.474121  1455.128052  256.961884
# 2022-12-30 21:00:00  0.000000  0.500000  5605.371094  1455.172974  257.088867
# 2022-12-30 22:00:00  0.000000  0.531250  5604.672852  1452.702026  257.069611
# 2022-12-30 23:00:00  0.000000  0.570312  5604.437988  1453.411011  257.346130
#
#                           T8503
# time
# 2018-01-02 00:00:00  278.437256
# 2018-01-02 01:00:00  279.093506
# 2018-01-02 02:00:00  279.292755
# 2018-01-02 03:00:00  279.247864
# 2018-01-02 04:00:00  280.121765
# ...                         ...
# 2022-12-30 19:00:00  281.517120
# 2022-12-30 20:00:00  282.021515
# 2022-12-30 21:00:00  281.514496
# 2022-12-30 22:00:00  281.291199
# 2022-12-30 23:00:00  280.736450
#
# [43511 rows x 101 columns]

# %%
import seaborn as sns
sns.set_theme(style="ticks")
df = df_all1k[["brfg_l","rh0","visibility0","cfl0"]].sample(100)
sns.pairplot(df, hue="brfg_l");
df["brfg_l"].value_counts()
# Out:
# No BR/FG    94
# BR/FG        6
# Name: brfg_l, dtype: int64

# %%
from sklearn.decomposition import PCA

df_pca = pd.DataFrame(PCA(n_components=3).fit_transform(df_all1k.iloc[:,1:]),
                                                        index =df_all1k.index)
df_pca["brfg_l"] = df_all1k.brfg_l
sns.pairplot(df_pca.sample(100), hue="brfg_l");

# %%
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyClassifier

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )


multiple_model = LazyClassifier(verbose =0, ignore_warnings = True,predictions=True)
models,predictions = multiple_model.fit(X_train,X_test,y_train,y_test)
# Out:
#  38%|███▊      | 11/29 [03:03<01:42,  5.72s/it]

# %%
models

# %% [markdown]
# **Meteorological model independent variables X**

# %%
df_all1k.iloc[:,1:].columns
# Out:
# Index(['dir0', 'snow_prec0', 'snowlevel0', 'mod0', 'wind_gust0', 'mslp0',
#        'temp0', 'rh0', 'visibility0', 'lhflx0', 'lwflx0', 'conv_prec0',
#        'prec0', 'swflx0', 'shflx0', 'cape0', 'cin0', 'cfh0', 'cfl0', 'cfm0',
#        'cft0', 'HGT5000', 'HGT8500', 'T5000', 'T8500', 'dir1', 'snow_prec1',
#        'snowlevel1', 'mod1', 'wind_gust1', 'mslp1', 'temp1', 'rh1',
#        'visibility1', 'lhflx1', 'lwflx1', 'conv_prec1', 'prec1', 'swflx1',
#        'shflx1', 'cape1', 'cin1', 'cfh1', 'cfl1', 'cfm1', 'cft1', 'HGT5001',
#        'HGT8501', 'T5001', 'T8501', 'dir2', 'snow_prec2', 'snowlevel2', 'mod2',
#        'wind_gust2', 'mslp2', 'temp2', 'rh2', 'visibility2', 'lhflx2',
#        'lwflx2', 'conv_prec2', 'prec2', 'swflx2', 'shflx2', 'cape2', 'cin2',
#        'cfh2', 'cfl2', 'cfm2', 'cft2', 'HGT5002', 'HGT8502', 'T5002', 'T8502',
#        'dir3', 'snow_prec3', 'snowlevel3', 'mod3', 'wind_gust3', 'mslp3',
#        'temp3', 'rh3', 'visibility3', 'lhflx3', 'lwflx3', 'conv_prec3',
#        'prec3', 'swflx3', 'shflx3', 'cape3', 'cin3', 'cfh3', 'cfl3', 'cfm3',
#        'cft3', 'HGT5003', 'HGT8503', 'T5003', 'T8503'],
#       dtype='object')

# %% [markdown]
# **ML LGBMClassifier. Samples 10. Heidke Skill score. Significance level (alpha) = 0.01 for normality test of HSS samples**

# %%
from lightgbm.sklearn import LGBMClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from scipy.stats import shapiro

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
#X = df_all1k.iloc[:,1:]
X = df_all1k.iloc[:,1:]

# loop random
HSS = []
for t in range (0,10):

  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #train model
  ml_model = LGBMClassifier(n_estimators=200).fit(X_res,y_res)

  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS[t],2))

  #quality report
  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
# if p-value is lower than 5%, we can reject the null hypothesis of the normality of the dataset

print(pd.DataFrame(HSS,columns=["HSS"]).describe())

#sample less 5000
sta, p = shapiro(HSS)
print("\np value:",p)
#significance level alpha=0.01
alpha = 0.01
if p>alpha:
  print("Accept null hypothesis: normal distribution variable HSS in the samples")
else:
  print("Reject null Hypothesis. Alternative hypothesis variable HSS no normal distribution in samples")  

pd.DataFrame(HSS,columns=["HSS"]).hist();
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       396       296   692
# No BR/FG    610      7401  8011
# All        1006      7697  8703
# Heidke Skill Score: 0.41
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.393638  0.572254  0.466431   692.000000
# No BR/FG       0.961543  0.923855  0.942322  8011.000000
# accuracy       0.895898  0.895898  0.895898     0.895898
# macro avg      0.677591  0.748055  0.704377  8703.000000
# weighted avg   0.916388  0.895898  0.904483  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       396       319   715
# No BR/FG    579      7409  7988
# All         975      7728  8703
# Heidke Skill Score: 0.41
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.406154  0.553846  0.468639   715.000000
# No BR/FG       0.958722  0.927516  0.942861  7988.000000
# accuracy       0.896817  0.896817  0.896817     0.896817
# macro avg      0.682438  0.740681  0.705750  8703.000000
# weighted avg   0.913325  0.896817  0.903901  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       396       304   700
# No BR/FG    647      7356  8003
# All        1043      7660  8703
# Heidke Skill Score: 0.4
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.379674  0.565714  0.454389   700.000000
# No BR/FG       0.960313  0.919155  0.939284  8003.000000
# accuracy       0.890727  0.890727  0.890727     0.890727
# macro avg      0.669994  0.742435  0.696836  8703.000000
# weighted avg   0.913611  0.890727  0.900283  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       380       344   724
# No BR/FG    635      7344  7979
# All        1015      7688  8703
# Heidke Skill Score: 0.38
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.374384  0.524862  0.437033   724.00000
# No BR/FG       0.955255  0.920416  0.937512  7979.00000
# accuracy       0.887510  0.887510  0.887510     0.88751
# macro avg      0.664820  0.722639  0.687272  8703.00000
# weighted avg   0.906932  0.887510  0.895877  8703.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       392       287   679
# No BR/FG    612      7412  8024
# All        1004      7699  8703
# Heidke Skill Score: 0.41
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.390438  0.577320  0.465835   679.000000
# No BR/FG       0.962722  0.923729  0.942823  8024.000000
# accuracy       0.896702  0.896702  0.896702     0.896702
# macro avg      0.676580  0.750524  0.704329  8703.000000
# weighted avg   0.918073  0.896702  0.905608  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       391       287   678
# No BR/FG    600      7425  8025
# All         991      7712  8703
# Heidke Skill Score: 0.41
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.394551  0.576696  0.468544   678.000000
# No BR/FG       0.962785  0.925234  0.943636  8025.000000
# accuracy       0.898081  0.898081  0.898081     0.898081
# macro avg      0.678668  0.750965  0.706090  8703.000000
# weighted avg   0.918517  0.898081  0.906624  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       410       289   699
# No BR/FG    599      7405  8004
# All        1009      7694  8703
# Heidke Skill Score: 0.43
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.406343  0.586552  0.480094   699.000000
# No BR/FG       0.962438  0.925162  0.943432  8004.000000
# accuracy       0.897966  0.897966  0.897966     0.897966
# macro avg      0.684391  0.755857  0.711763  8703.000000
# weighted avg   0.917774  0.897966  0.906218  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       379       291   670
# No BR/FG    588      7445  8033
# All         967      7736  8703
# Heidke Skill Score: 0.41
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score   support
# BR/FG          0.391934  0.565672  0.463042   670.000
# No BR/FG       0.962384  0.926802  0.944258  8033.000
# accuracy       0.899000  0.899000  0.899000     0.899
# macro avg      0.677159  0.746237  0.703650  8703.000
# weighted avg   0.918468  0.899000  0.907211  8703.000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       397       319   716
# No BR/FG    623      7364  7987
# All        1020      7683  8703
# Heidke Skill Score: 0.4
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.389216  0.554469  0.457373   716.000000
# No BR/FG       0.958480  0.921998  0.939885  7987.000000
# accuracy       0.891761  0.891761  0.891761     0.891761
# macro avg      0.673848  0.738234  0.698629  8703.000000
# weighted avg   0.911646  0.891761  0.900189  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       417       294   711
# No BR/FG    631      7361  7992
# All        1048      7655  8703
# Heidke Skill Score: 0.42
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.397901  0.586498  0.474133   711.000000
# No BR/FG       0.961594  0.921046  0.940883  7992.000000
# accuracy       0.893715  0.893715  0.893715     0.893715
# macro avg      0.679747  0.753772  0.707508  8703.000000
# weighted avg   0.915542  0.893715  0.902752  8703.000000
#
# HSS stadistics
#              HSS
# count  10.000000
# mean    0.407368
# std     0.013684
# min     0.376483
# 25%     0.401804
# 50%     0.410970
# 75%     0.414022
# max     0.425585
#
# p value: 0.18682296574115753
# Accept null hypothesis: normal distribution variable HSS in the samples

# %% [markdown]
# **Add time features**

# %%
df_all1k["hour"] = df_all1k.index.hour
df_all1k["month"] = df_all1k.index.month
df_all1k["dayofyear"] = df_all1k.index.dayofyear
df_all1k["weekofyear"] = df_all1k.index.isocalendar().week.astype(int)

# %%
df_all1k.iloc[:,1:].columns
# Out:
# Index(['dir0', 'snow_prec0', 'snowlevel0', 'mod0', 'wind_gust0', 'mslp0',
#        'temp0', 'rh0', 'visibility0', 'lhflx0',
#        ...
#        'cfm3', 'cft3', 'HGT5003', 'HGT8503', 'T5003', 'T8503', 'hour', 'month',
#        'dayofyear', 'weekofyear'],
#       dtype='object', length=104)

# %%
# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

multiple_model = LazyClassifier(verbose =0, ignore_warnings = True,predictions=True)
models,predictions = multiple_model.fit(X_train,X_test,y_train,y_test)
models
# Out:
# 100%|██████████| 29/29 [00:58<00:00,  2.01s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LabelPropagation                   0.88               0.81    None      0.88
# LabelSpreading                     0.88               0.81    None      0.88
# ExtraTreesClassifier               0.90               0.79    None      0.90
# LGBMClassifier                     0.90               0.79    None      0.89
# BaggingClassifier                  0.88               0.78    None      0.88
# RandomForestClassifier             0.90               0.78    None      0.89
# KNeighborsClassifier               0.88               0.77    None      0.88
# Perceptron                         0.83               0.75    None      0.83
# DecisionTreeClassifier             0.85               0.75    None      0.85
# ExtraTreeClassifier                0.84               0.75    None      0.84
# QuadraticDiscriminantAnalysis      0.76               0.75    None      0.78
# GaussianNB                         0.76               0.74    None      0.79
# BernoulliNB                        0.75               0.74    None      0.77
# NearestCentroid                    0.75               0.74    None      0.78
# SGDClassifier                      0.85               0.73    None      0.85
# XGBClassifier                      0.88               0.73    None      0.87
# AdaBoostClassifier                 0.87               0.73    None      0.86
# LogisticRegression                 0.86               0.71    None      0.85
# CalibratedClassifierCV             0.86               0.71    None      0.85
# LinearDiscriminantAnalysis         0.86               0.70    None      0.85
# SVC                                0.87               0.70    None      0.86
# LinearSVC                          0.86               0.70    None      0.85
# PassiveAggressiveClassifier        0.83               0.69    None      0.82
# RidgeClassifierCV                  0.86               0.67    None      0.84
# RidgeClassifier                    0.86               0.66    None      0.84
# DummyClassifier                    0.82               0.50    None      0.74
#
#                                Time Taken
# Model
# LabelPropagation                     7.42
# LabelSpreading                      11.21
# ExtraTreesClassifier                 1.45
# LGBMClassifier                       0.96
# BaggingClassifier                    4.67
# RandomForestClassifier               6.96
# KNeighborsClassifier                 1.20
# Perceptron                           0.19
# DecisionTreeClassifier               0.81
# ExtraTreeClassifier                  0.08
# QuadraticDiscriminantAnalysis        0.28
# GaussianNB                           0.08
# BernoulliNB                          0.12
# NearestCentroid                      0.19
# SGDClassifier                        0.21
# XGBClassifier                        2.69
# AdaBoostClassifier                   3.98
# LogisticRegression                   0.69
# CalibratedClassifierCV               6.03
# LinearDiscriminantAnalysis           0.23
# SVC                                  5.71
# LinearSVC                            2.36
# PassiveAggressiveClassifier          0.20
# RidgeClassifierCV                    0.25
# RidgeClassifier                      0.12
# DummyClassifier                      0.07

# %%
from lightgbm.sklearn import LGBMClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.tree import ExtraTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from scipy.stats import shapiro

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]
#X = df_all1k[["rh0","visibility0","mod0","rh1","visibility1","mod1",'hour', 'month','dayofyear']]

# loop random
HSS_a = []
for t in range (0,10):

  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #train model
  ml_model = LGBMClassifier(n_estimators=200).fit(X_res,y_res)
  #ml_model = ExtraTreeClassifier().fit(X_res,y_res)
  #ml_model = Perceptron().fit(X_res,y_res)
  #ml_model = RandomForestClassifier().fit(X_res,y_res)

  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_a.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_a[t],2))

  #quality report
  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
# if p-value is lower than 1%, we can reject the null hypothesis of the normality of the dataset

print(pd.DataFrame(HSS_a,columns=["HSS"]).describe())

#sample less 5000
sta, p = shapiro(HSS_a)
print("\np value:",p)

#significance level alpha=0.01
alpha = 0.01
if p>alpha:
  print("Accept null Hypothesis: normal distribution variable HSS in the samples")
else:
  print("Reject null Hypothesis. Alternative hypothesis variable HSS no normal distribution in samples")  

pd.DataFrame(HSS_a,columns=["HSS_a"]).hist();
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       394       298   692
# No BR/FG    495      7516  8011
# All         889      7814  8703
# Heidke Skill Score: 0.45
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.443195  0.569364  0.498419   692.000000
# No BR/FG       0.961863  0.938210  0.949889  8011.000000
# accuracy       0.908882  0.908882  0.908882     0.908882
# macro avg      0.702529  0.753787  0.724154  8703.000000
# weighted avg   0.920623  0.908882  0.913992  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       406       309   715
# No BR/FG    481      7507  7988
# All         887      7816  8703
# Heidke Skill Score: 0.46
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.457723  0.567832  0.506866   715.000000
# No BR/FG       0.960466  0.939785  0.950013  7988.000000
# accuracy       0.909227  0.909227  0.909227     0.909227
# macro avg      0.709094  0.753808  0.728440  8703.000000
# weighted avg   0.919163  0.909227  0.913606  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       395       305   700
# No BR/FG    480      7523  8003
# All         875      7828  8703
# Heidke Skill Score: 0.45
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.451429  0.564286  0.501587   700.000000
# No BR/FG       0.961037  0.940022  0.950414  8003.000000
# accuracy       0.909801  0.909801  0.909801     0.909801
# macro avg      0.706233  0.752154  0.726001  8703.000000
# weighted avg   0.920048  0.909801  0.914314  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       399       325   724
# No BR/FG    496      7483  7979
# All         895      7808  8703
# Heidke Skill Score: 0.44
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.445810  0.551105  0.492897   724.000000
# No BR/FG       0.958376  0.937837  0.947995  7979.000000
# accuracy       0.905665  0.905665  0.905665     0.905665
# macro avg      0.702093  0.744471  0.720446  8703.000000
# weighted avg   0.915736  0.905665  0.910136  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       398       281   679
# No BR/FG    464      7560  8024
# All         862      7841  8703
# Heidke Skill Score: 0.47
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.461717  0.586156  0.516548   679.000000
# No BR/FG       0.964163  0.942173  0.953041  8024.000000
# accuracy       0.914397  0.914397  0.914397     0.914397
# macro avg      0.712940  0.764165  0.734794  8703.000000
# weighted avg   0.924962  0.914397  0.918986  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       404       274   678
# No BR/FG    451      7574  8025
# All         855      7848  8703
# Heidke Skill Score: 0.48
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.472515  0.595870  0.527071   678.000000
# No BR/FG       0.965087  0.943801  0.954325  8025.000000
# accuracy       0.916695  0.916695  0.916695     0.916695
# macro avg      0.718801  0.769835  0.740698  8703.000000
# weighted avg   0.926713  0.916695  0.921040  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       422       277   699
# No BR/FG    461      7543  8004
# All         883      7820  8703
# Heidke Skill Score: 0.49
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.477916  0.603720  0.533502   699.000000
# No BR/FG       0.964578  0.942404  0.953362  8004.000000
# accuracy       0.915202  0.915202  0.915202     0.915202
# macro avg      0.721247  0.773062  0.743432  8703.000000
# weighted avg   0.925491  0.915202  0.919640  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       398       272   670
# No BR/FG    475      7558  8033
# All         873      7830  8703
# Heidke Skill Score: 0.47
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.455899  0.594030  0.515878   670.000000
# No BR/FG       0.965262  0.940869  0.952909  8033.000000
# accuracy       0.914168  0.914168  0.914168     0.914168
# macro avg      0.710581  0.767449  0.734394  8703.000000
# weighted avg   0.926049  0.914168  0.919264  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       431       285   716
# No BR/FG    502      7485  7987
# All         933      7770  8703
# Heidke Skill Score: 0.47
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.461951  0.601955  0.522741   716.000000
# No BR/FG       0.963320  0.937148  0.950054  7987.000000
# accuracy       0.909571  0.909571  0.909571     0.909571
# macro avg      0.712636  0.769552  0.736397  8703.000000
# weighted avg   0.922073  0.909571  0.914899  8703.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       428       283   711
# No BR/FG    483      7509  7992
# All         911      7792  8703
# Heidke Skill Score: 0.48
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.469813  0.601969  0.527744   711.000000
# No BR/FG       0.963681  0.939565  0.951470  7992.000000
# accuracy       0.911984  0.911984  0.911984     0.911984
# macro avg      0.716747  0.770767  0.739607  8703.000000
# weighted avg   0.923334  0.911984  0.916853  8703.000000
#
# HSS stadistics
#              HSS
# count  10.000000
# mean    0.466427
# std     0.015426
# min     0.441531
# 25%     0.453883
# 50%     0.469997
# 75%     0.478457
# max     0.487557
#
# p value: 0.6707239151000977
# Accept null Hypothesis: normal distribution variable HSS in the samples

# %%
feature_importances = ml_model.feature_importances_
total_sum = sum(feature_importances)
feature_importances_perc = [(importance/total_sum)*100 for importance in feature_importances]
# Print the feature importances as a percentage of total feature importance

for name, importance in zip(X.columns, feature_importances_perc):
    print(f"{name}: {importance:.1f}%")
# Out:
# dir0: 1.4%
# snow_prec0: 0.0%
# snowlevel0: 0.7%
# mod0: 2.1%
# wind_gust0: 2.4%
# mslp0: 0.7%
# temp0: 1.7%
# rh0: 2.5%
# visibility0: 1.1%
# lhflx0: 1.7%
# lwflx0: 0.8%
# conv_prec0: 0.1%
# prec0: 0.4%
# swflx0: 1.1%
# shflx0: 1.1%
# cape0: 0.4%
# cin0: 0.5%
# cfh0: 0.5%
# cfl0: 0.7%
# cfm0: 0.4%
# cft0: 0.7%
# HGT5000: 0.7%
# HGT8500: 0.8%
# T5000: 0.7%
# T8500: 0.8%
# dir1: 1.4%
# snow_prec1: 0.0%
# snowlevel1: 0.7%
# mod1: 1.8%
# wind_gust1: 2.4%
# mslp1: 0.8%
# temp1: 1.5%
# rh1: 2.5%
# visibility1: 1.2%
# lhflx1: 2.1%
# lwflx1: 0.8%
# conv_prec1: 0.1%
# prec1: 0.4%
# swflx1: 1.2%
# shflx1: 0.9%
# cape1: 0.4%
# cin1: 0.5%
# cfh1: 0.5%
# cfl1: 0.7%
# cfm1: 0.4%
# cft1: 0.7%
# HGT5001: 0.7%
# HGT8501: 0.8%
# T5001: 0.7%
# T8501: 0.8%
# dir2: 1.4%
# snow_prec2: 0.0%
# snowlevel2: 0.8%
# mod2: 1.5%
# wind_gust2: 2.0%
# mslp2: 0.8%
# temp2: 1.3%
# rh2: 1.6%
# visibility2: 0.9%
# lhflx2: 1.5%
# lwflx2: 0.8%
# conv_prec2: 0.1%
# prec2: 0.4%
# swflx2: 1.2%
# shflx2: 0.9%
# cape2: 0.4%
# cin2: 0.5%
# cfh2: 0.5%
# cfl2: 0.8%
# cfm2: 0.4%
# cft2: 0.7%
# HGT5002: 0.7%
# HGT8502: 0.8%
# T5002: 0.7%
# T8502: 0.7%
# dir3: 1.3%
# snow_prec3: 0.0%
# snowlevel3: 0.8%
# mod3: 1.7%
# wind_gust3: 2.3%
# mslp3: 0.8%
# temp3: 1.4%
# rh3: 1.9%
# visibility3: 0.8%
# lhflx3: 1.9%
# lwflx3: 0.8%
# conv_prec3: 0.1%
# prec3: 0.4%
# swflx3: 1.2%
# shflx3: 0.8%
# cape3: 0.4%
# cin3: 0.5%
# cfh3: 0.5%
# cfl3: 0.7%
# cfm3: 0.4%
# cft3: 0.6%
# HGT5003: 0.7%
# HGT8503: 0.8%
# T5003: 0.7%
# T8503: 0.8%
# hour: 5.6%
# month: 1.0%
# dayofyear: 0.9%
# weekofyear: 0.9%

# %% [markdown]
# **Test association between observed variable and machine learning forecast (Pearson’s chi square test). Significance level (alpha) = 0.01**

# %%
from scipy.stats import chi2_contingency

print("Last confusion matrix\n")
print(cm.iloc[0:2,0:2])

#stadistic(sta), pvalue (p), degrees of freedom (dof) and expected values (exp)
sta, p, dof, exp = chi2_contingency(cm.iloc[0:2,0:2])

#degrees of freedoom (rows-1)*(columns-1) to test associationbetween two variables
alpha = 0.01
print('\np-value:',p)
print('Significance level:',alpha)
print('Degres of of freedom: ',dof)
print("Stadistic",sta)

if p<=alpha:
    print("Reject H0,There is an association between machine learning forecast and observed values")
else:
    print("Retain H0,There is no association between machine learning forecast and observed values")
# Out:
# Last confusion matrix
#
# col_0     BR/FG  No BR/FG
# brfg_l
# BR/FG       428       283
# No BR/FG    483      7509
#
# p-value: 0.0
# Significance level: 0.01
# Degres of of freedom:  1
# Stadistic 2037.2692295281247
# Reject H0,There is an association between machine learning forecast and observed values

# %% [markdown]
# **T test two related samples. This is a test for the null hypothesis that two related samples have identical HSS means. Alternative hypothesis the mean of the distribution underlying the sample without time variables is less than the mean of the distribution underlying the sample with time variables. Significance level (alpha) = 0.01**

# %%
from scipy import stats

alpha = 0.01
sta, p_value = stats.ttest_rel(HSS, HSS_a, alternative="less")

print("\nmeans without time variables:", np.round(HSS,2))
print("\nmeans with time variables:", np.round(HSS_a,2))

print("\nalpha: ",alpha)

print("\np_value point: ",p_value)
if p_value < alpha:    
    print("\nwe are rejecting null hypothesis  H0: HHS mean without time variables = HSS mean with time variables")
    print("\nwe are accepting alternative hypothesis: the HSS mean of the sample without time variables inputs is less than the HSS mean of the sample with time variables inputs")
else:
    print("\nwe are accepting null hypothesis:  H0: HSS mean without time variables = HSS mean with time variables ")
# Out:
# means without time variables: [0.41 0.41 0.4  0.38 0.41 0.41 0.43 0.41 0.4  0.42]
#
# means with time variables: [0.45 0.46 0.45 0.44 0.47 0.48 0.49 0.47 0.47 0.48]
#
# alpha:  0.01
#
# p_value point:  1.4529481355264592e-08
#
# we are rejecting null hypothesis  H0: HHS mean without time variables = HSS mean with time variables
#
# we are accepting alternative hypothesis: the HSS mean of the sample without time variables inputs is less than the HSS mean of the sample with time variables inputs

# %%
import pickle
from sklearn.pipeline import Pipeline

estimators = [('ml_model', ml_model)]
pipe = Pipeline(estimators)
print(pipe)
al_file={"x_var":X.columns,"coor":coor,"pipe":pipe}
pickle.dump(al_file, open("brfg_LECO_d1.al", 'wb'))
# Out:
# Pipeline(steps=[('ml_model', LGBMClassifier(n_estimators=200))])

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.1

# %% [markdown]
# **Best algorithm too heavy to upload in github!!**

# %%
df_all1k.iloc[:,1:].columns
# Out:
# Index(['dir0', 'snow_prec0', 'snowlevel0', 'mod0', 'wind_gust0', 'mslp0',
#        'temp0', 'rh0', 'visibility0', 'lhflx0',
#        ...
#        'cfm3', 'cft3', 'HGT5003', 'HGT8503', 'T5003', 'T8503', 'hour', 'month',
#        'dayofyear', 'weekofyear'],
#       dtype='object', length=104)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

# loop random
HSS_b = []
for t in range (0,10):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  ml_model = ExtraTreesClassifier(n_estimators=300).fit(X_res,y_res)

  #Confussion matrix

  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_b.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_b[t],2))

  #quality report

  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
pd.DataFrame(HSS_b,columns=["HSS"]).describe()
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       322       181   503
# No BR/FG    199      5825  6024
# All         521      6006  6527
# Heidke Skill Score: 0.6
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.618042  0.640159  0.628906   503.00000
# No BR/FG       0.969863  0.966965  0.968412  6024.00000
# accuracy       0.941780  0.941780  0.941780     0.94178
# macro avg      0.793953  0.803562  0.798659  6527.00000
# weighted avg   0.942751  0.941780  0.942248  6527.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       345       211   556
# No BR/FG    173      5798  5971
# All         518      6009  6527
# Heidke Skill Score: 0.61
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.666023  0.620504  0.642458   556.000000
# No BR/FG       0.964886  0.971027  0.967947  5971.000000
# accuracy       0.941167  0.941167  0.941167     0.941167
# macro avg      0.815455  0.795765  0.805202  6527.000000
# weighted avg   0.939427  0.941167  0.940220  6527.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       333       178   511
# No BR/FG    185      5831  6016
# All         518      6009  6527
# Heidke Skill Score: 0.62
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.642857  0.651663  0.647230   511.000000
# No BR/FG       0.970378  0.969249  0.969813  6016.000000
# accuracy       0.944385  0.944385  0.944385     0.944385
# macro avg      0.806617  0.810456  0.808522  6527.000000
# weighted avg   0.944736  0.944385  0.944558  6527.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       339       204   543
# No BR/FG    177      5807  5984
# All         516      6011  6527
# Heidke Skill Score: 0.61
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.656977  0.624309  0.640227   543.000000
# No BR/FG       0.966062  0.970421  0.968237  5984.000000
# accuracy       0.941627  0.941627  0.941627     0.941627
# macro avg      0.811519  0.797365  0.804232  6527.000000
# weighted avg   0.940349  0.941627  0.940949  6527.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       357       211   568
# No BR/FG    203      5756  5959
# All         560      5967  6527
# Heidke Skill Score: 0.6
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.637500  0.628521  0.632979   568.000000
# No BR/FG       0.964639  0.965934  0.965286  5959.000000
# accuracy       0.936571  0.936571  0.936571     0.936571
# macro avg      0.801069  0.797228  0.799132  6527.000000
# weighted avg   0.936170  0.936571  0.936368  6527.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       325       181   506
# No BR/FG    185      5836  6021
# All         510      6017  6527
# Heidke Skill Score: 0.61
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.637255  0.642292  0.639764   506.000000
# No BR/FG       0.969919  0.969274  0.969596  6021.000000
# accuracy       0.943925  0.943925  0.943925     0.943925
# macro avg      0.803587  0.805783  0.804680  6527.000000
# weighted avg   0.944129  0.943925  0.944026  6527.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       342       183   525
# No BR/FG    210      5792  6002
# All         552      5975  6527
# Heidke Skill Score: 0.6
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.619565  0.651429  0.635097   525.000000
# No BR/FG       0.969372  0.965012  0.967187  6002.000000
# accuracy       0.939789  0.939789  0.939789     0.939789
# macro avg      0.794469  0.808220  0.801142  6527.000000
# weighted avg   0.941236  0.939789  0.940475  6527.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       337       214   551
# No BR/FG    177      5799  5976
# All         514      6013  6527
# Heidke Skill Score: 0.6
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.655642  0.611615  0.632864   551.000000
# No BR/FG       0.964410  0.970382  0.967387  5976.000000
# accuracy       0.940095  0.940095  0.940095     0.940095
# macro avg      0.810026  0.790998  0.800125  6527.000000
# weighted avg   0.938345  0.940095  0.939147  6527.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       304       191   495
# No BR/FG    195      5837  6032
# All         499      6028  6527
# Heidke Skill Score: 0.58
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.609218  0.614141  0.611670   495.000000
# No BR/FG       0.968315  0.967672  0.967993  6032.000000
# accuracy       0.940861  0.940861  0.940861     0.940861
# macro avg      0.788766  0.790907  0.789832  6527.000000
# weighted avg   0.941081  0.940861  0.940970  6527.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       319       196   515
# No BR/FG    214      5798  6012
# All         533      5994  6527
# Heidke Skill Score: 0.57
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.598499  0.619417  0.608779   515.000000
# No BR/FG       0.967301  0.964405  0.965850  6012.000000
# accuracy       0.937184  0.937184  0.937184     0.937184
# macro avg      0.782900  0.791911  0.787315  6527.000000
# weighted avg   0.938201  0.937184  0.937676  6527.000000
#
# HSS stadistics
#              HSS
# count  10.000000
# mean    0.599784
# std     0.013462
# min     0.574640
# 25%     0.597563
# 50%     0.601300
# 75%     0.609142
# max     0.617045

# %% [markdown]
# **T test two related samples. This is a test for the null hypothesis that two related samples have identical HSS means. Alternative hypothesis the mean of the distribution underlying the sample without time variables is less than the mean of the distribution underlying the sample with time variables. Significance level (alpha) = 0.01**

# %%
from scipy import stats

alpha = 0.01
sta, p_value = stats.ttest_rel(HSS_a, HSS_b, alternative="less")

print("\nHSS LGBMClassifier:", np.round(HSS_a,2))
print("\nHSS ExtraTreesClassifier:", np.round(HSS_b,2))

print("\nalpha: ",alpha)

print("\np_value point: ",p_value)
if p_value < alpha:    
    print("\nwe are rejecting null hypothesis  H0: HHS mean ExtraTreesClassifier = HSS mean with LGBMClassifier")
    print("\nwe are accepting alternative hypothesis: the HSS mean of the sample LGBMClassifier is less than the HSS mean of the sample with ExtraTreesClassifier")
else:
    print("\nwe are accepting null hypothesis:  H0: HSS mean LGBMClassifier = HSS mean with ExtraTreesClassifier")
# Out:
# HSS LGBMClassifier: [0.45 0.46 0.45 0.44 0.47 0.48 0.49 0.47 0.47 0.48]
#
# HSS ExtraTreesClassifier: [0.6  0.61 0.62 0.61 0.6  0.61 0.6  0.6  0.58 0.57]
#
# alpha:  0.01
#
# p_value point:  1.6504030151395092e-08
#
# we are rejecting null hypothesis  H0: HHS mean ExtraTreesClassifier = HSS mean with LGBMClassifier
#
# we are accepting alternative hypothesis: the HSS mean of the sample LGBMClassifier is less than the HSS mean of the sample with ExtraTreesClassifier

# %% [markdown]
# **PCA components**

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

# loop random
HSS_pca = []
for t in range (0,10):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #scaler
  sc = StandardScaler().fit(X_res)
  X_sc = sc.transform(X_res)

  #PCA
  n_components = len(X.columns)
  pca = PCA(n_components).fit(X_sc)
  X_pca = pca.transform(X_sc)

  #machine learning model
  #ml_model = ExtraTreesClassifier(n_estimators=150).fit(X_pca,y_res)
  ml_model = MLPClassifier(hidden_layer_sizes=(100,50,10)).fit(X_pca,y_res)
  
  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  y_pca = pca.transform(sc.transform(X_test))
  cm = pd.crosstab(y_test, ml_model.predict(y_pca),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_pca.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_pca[t],2))

  #quality report

  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(y_pca),output_dict=True)).T)

print("\nHSS stadistics")
pd.DataFrame(HSS_pca,columns=["HSS_pca"]).describe()
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       287       150   437
# No BR/FG    179      1855  2034
# All         466      2005  2471
# Heidke Skill Score: 0.55
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.615880  0.656751  0.635659   437.000000
# No BR/FG       0.925187  0.911996  0.918544  2034.000000
# accuracy       0.866856  0.866856  0.866856     0.866856
# macro avg      0.770533  0.784373  0.777102  2471.000000
# weighted avg   0.870486  0.866856  0.868516  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       288       173   461
# No BR/FG    208      1802  2010
# All         496      1975  2471
# Heidke Skill Score: 0.51
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.580645  0.624729  0.601881   461.000000
# No BR/FG       0.912405  0.896517  0.904391  2010.000000
# accuracy       0.845811  0.845811  0.845811     0.845811
# macro avg      0.746525  0.760623  0.753136  2471.000000
# weighted avg   0.850511  0.845811  0.847954  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       348       119   467
# No BR/FG    214      1790  2004
# All         562      1909  2471
# Heidke Skill Score: 0.59
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.619217  0.745182  0.676385   467.000000
# No BR/FG       0.937664  0.893214  0.914899  2004.000000
# accuracy       0.865237  0.865237  0.865237     0.865237
# macro avg      0.778440  0.819198  0.795642  2471.000000
# weighted avg   0.877480  0.865237  0.869822  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       300       149   449
# No BR/FG    139      1883  2022
# All         439      2032  2471
# Heidke Skill Score: 0.6
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.683371  0.668151  0.675676   449.000000
# No BR/FG       0.926673  0.931256  0.928959  2022.000000
# accuracy       0.883448  0.883448  0.883448     0.883448
# macro avg      0.805022  0.799704  0.802317  2471.000000
# weighted avg   0.882463  0.883448  0.882935  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       273       176   449
# No BR/FG    136      1886  2022
# All         409      2062  2471
# Heidke Skill Score: 0.56
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.667482  0.608018  0.636364   449.000000
# No BR/FG       0.914646  0.932740  0.923604  2022.000000
# accuracy       0.873735  0.873735  0.873735     0.873735
# macro avg      0.791064  0.770379  0.779984  2471.000000
# weighted avg   0.869734  0.873735  0.871410  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       295       164   459
# No BR/FG    148      1864  2012
# All         443      2028  2471
# Heidke Skill Score: 0.58
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.665914  0.642702  0.654102   459.000000
# No BR/FG       0.919132  0.926441  0.922772  2012.000000
# accuracy       0.873735  0.873735  0.873735     0.873735
# macro avg      0.792523  0.784571  0.788437  2471.000000
# weighted avg   0.872096  0.873735  0.872865  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       337       154   491
# No BR/FG    176      1804  1980
# All         513      1958  2471
# Heidke Skill Score: 0.59
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.656920  0.686354  0.671315   491.000000
# No BR/FG       0.921348  0.911111  0.916201  1980.000000
# accuracy       0.866451  0.866451  0.866451     0.866451
# macro avg      0.789134  0.798733  0.793758  2471.000000
# weighted avg   0.868805  0.866451  0.867541  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       308       178   486
# No BR/FG    155      1830  1985
# All         463      2008  2471
# Heidke Skill Score: 0.57
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.665227  0.633745  0.649104   486.000000
# No BR/FG       0.911355  0.921914  0.916604  1985.000000
# accuracy       0.865237  0.865237  0.865237     0.865237
# macro avg      0.788291  0.777830  0.782854  2471.000000
# weighted avg   0.862946  0.865237  0.863992  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       280       166   446
# No BR/FG    179      1846  2025
# All         459      2012  2471
# Heidke Skill Score: 0.53
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score     support
# BR/FG          0.610022  0.627803  0.618785   446.00000
# No BR/FG       0.917495  0.911605  0.914541  2025.00000
# accuracy       0.860380  0.860380  0.860380     0.86038
# macro avg      0.763758  0.769704  0.766663  2471.00000
# weighted avg   0.861998  0.860380  0.861158  2471.00000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       285       165   450
# No BR/FG    164      1857  2021
# All         449      2022  2471
# Heidke Skill Score: 0.55
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.634744  0.633333  0.634038   450.000000
# No BR/FG       0.918398  0.918852  0.918625  2021.000000
# accuracy       0.866856  0.866856  0.866856     0.866856
# macro avg      0.776571  0.776093  0.776331  2471.000000
# weighted avg   0.866741  0.866856  0.866798  2471.000000
#
# HSS stadistics
#          HSS_pca
# count  10.000000
# mean    0.563400
# std     0.029173
# min     0.506431
# 25%     0.553074
# 50%     0.562969
# 75%     0.584901
# max     0.604646
